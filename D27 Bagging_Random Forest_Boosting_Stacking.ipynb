# %% [markdown]
# # Ensemble techniques

# %% [markdown]
# ## D 27 Bagging_Random Forest_Boosting_Stacking.ipynb

# %% [markdown]
# ### Bagged Decision Trees for Classification

# %%
# Bagged Decision Trees for Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]

seed = 7
kfold = KFold(n_splits=10)
cart = DecisionTreeClassifier()
num_trees = 100

model = BaggingClassifier(estimator=cart, n_estimators=num_trees, random_state=seed)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())


# It involves training multiple models on different subsets of the data and averaging their predictions to reduce varianc
# improves the stability and accuracy
# 10-fold cross-validation and stores the results in the results variable
# num_trees = 100 --> 100subsets
# cross-validation.
# Result = cross-validation mean
# Out:
# 0.7720437457279563

# %%
"""
# Decession Tree Using Enthropy

from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test = train_test_split(X,Y, test_size=0.2,random_state=40)

model = DecisionTreeClassifier(criterion = 'entropy',max_depth=num_trees)
model.fit(x_train,y_train)

from sklearn import tree
tree.plot_tree(model);

"""
# random_state=40 any thing
# data will be split in the same way every time you run the code.
# This is helpful for comparing results across different runs.
# Out:
# array([0.84415584, 0.75324675, 0.74025974, 0.81818182, 0.79220779,
#        0.79220779, 0.63636364, 0.79220779, 0.80263158, 0.76315789])

# %% [markdown]
# ### Random Forest Classification

# %%
# Random Forest Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

X = array[:,0:8]
Y = array[:,8]

num_trees = 100
max_features = 3
# 8 independent samples X take max 3 samples in each  sample

kfold = KFold(n_splits=10, random_state=7, shuffle= True)

# By defalult it take decession tree
model = RandomForestClassifier(n_estimators=num_trees, max_features=max_features)
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.7721291866028708

# %%
# randomly select no.of columns , subsets
# 1st decession tree no.of feacures = 3
# 2st decession tree no.of feacures = 2
# 3st decession tree no.of feacures = 2
# RF: a machine learning algorithm that uses multiple decision trees to make predictions
# num_trees = 100 subsets --> dession tree --> predection

# %% [markdown]
# ### AdaBoost Classification

# %%
# AdaBoost Classification

import warnings
warnings.filterwarnings("ignore")

from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier

filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

dataframe = read_csv(filename, names=names)
array = dataframe.values

X = array[:,0:8]
Y = array[:,8]

num_trees = 10
seed=7

# kfold = KFold(n_splits=10, random_state=seed , shuffle= True)
kfold = KFold(n_splits=10)

#model = AdaBoostClassifier(n_estimators=num_trees, random_state=seed)
model = AdaBoostClassifier()
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.7539473684210527

# %% [markdown]
# ### Stacking Ensemble for Classification

# %%
# Stacking Ensemble for Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier


filename = 'pima-indians-diabetes.data.csv'
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = read_csv(filename, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
kfold = KFold(n_splits=10, random_state=7 , shuffle= True)

# create the sub models
estimators = []
model1 = LogisticRegression(max_iter=500)
estimators.append(('logistic', model1))

model2 = DecisionTreeClassifier()
estimators.append(('cart', model2))

model3 = SVC()
estimators.append(('svm', model3))

# create the ensemble model
ensemble = VotingClassifier(estimators)
results = cross_val_score(ensemble, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.773462064251538

# %%
"""
The results array contains the accuracy scores for each of the 10 folds.

results.mean() gives the average accuracy score across all folds.

Use of Results:

The mean accuracy score provides a measure of how well the model is likely to perform on unseen data. It helps in assessing the model’s generalization performance and can be used to compare different models or configurations.

"""

# %%
# https://drive.google.com/file/d/1WRObobRGKtfWEDPYFCed-mX7foF3G8c2/view?usp=drive_link

# %%
import pandas as pd

file_id='1WRObobRGKtfWEDPYFCed-mX7foF3G8c2'

url=f'https://drive.google.com/uc?id={file_id}'
df=pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-21-41e71deaa5d6> in <cell line: 6>()
#       4
#       5 url=f'https://drive.google.com/uc?id={file_id}'
# ----> 6 df=pd.read_csv(url)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
